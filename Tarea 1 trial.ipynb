# %% [markdown]
# # Importar datos

# %%
import pandas as pd
from pandas.io.json import json_normalize
import warnings
warnings.filterwarnings("ignore")
print("first thing done")
import os
print(os.getcwd())
# Out:
# first thing done
# C:\Users\paris\Desktop\proyectoEsp\tarea1

# %% [markdown]
# ## cargar datos a dataframe pandas

# %%
raw_tweets = pd.read_json(r'farmers-protest-tweets-2021-2-4.json', lines=True)
print("loaded")
# Out:
# loaded

# %%
raw_tweets = raw_tweets[raw_tweets['lang']=='en']
print("Shape: ", raw_tweets.shape)
# Out:
# Shape:  (48429, 21)

# %%
users = json_normalize(raw_tweets['user'])
users.drop(['description', 'linkTcourl'], axis=1, inplace=True)
users.rename(columns={'id':'userId', 'url':'profileUrl'}, inplace=True)
users.head(5)
# Out:
#           username        displayname               userId  \
# 0  ArjunSinghPanam  Arjun Singh Panam             45091142
# 1       PrdeepNain       Pradeep Nain  1355092620662329349
# 2    anmoldhaliwal              Anmol            137908912
# 3    anmoldhaliwal              Anmol            137908912
# 4    anmoldhaliwal              Anmol            137908912
#
#                                       rawDescription descriptionUrls  \
# 0  Global Citizen, Actor, Director: Sky is the ro...              []
# 1              Live in the sunshine where you belong              []
# 2                                        coming soon              []
# 3                                        coming soon              []
# 4                                        coming soon              []
#
#    verified                    created  followersCount  friendsCount  \
# 0     False  2009-06-06T07:50:57+00:00             603           311
# 1     False  2021-01-29T09:58:06+00:00              14           134
# 2     False  2010-04-28T03:12:18+00:00              51            27
# 3     False  2010-04-28T03:12:18+00:00              51            27
# 4     False  2010-04-28T03:12:18+00:00              51            27
#
#    statusesCount  favouritesCount  listedCount  mediaCount      location  \
# 0          17534             4269           23        1211
# 1            160              240            0         102
# 2            228               77            0          12  Brampton, On
# 3            228               77            0          12  Brampton, On
# 4            228               77            0          12  Brampton, On
#
#    protected                              linkUrl  \
# 0      False  https://www.cosmosmovieofficial.com
# 1      False                                 None
# 2      False                                 None
# 3      False                                 None
# 4      False                                 None
#
#                                      profileImageUrl  \
# 0  https://pbs.twimg.com/profile_images/121554174...
# 1  https://pbs.twimg.com/profile_images/136417063...
# 2  https://pbs.twimg.com/profile_images/156497514...
# 3  https://pbs.twimg.com/profile_images/156497514...
# 4  https://pbs.twimg.com/profile_images/156497514...
#
#                                     profileBannerUrl  \
# 0  https://pbs.twimg.com/profile_banners/45091142...
# 1  https://pbs.twimg.com/profile_banners/13550926...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                             profileUrl
# 0  https://twitter.com/ArjunSinghPanam
# 1       https://twitter.com/PrdeepNain
# 2    https://twitter.com/anmoldhaliwal
# 3    https://twitter.com/anmoldhaliwal
# 4    https://twitter.com/anmoldhaliwal

# %%
users = pd.DataFrame(users)
users.drop_duplicates(subset=['userId'], inplace=True)
print("Shape: ", users.shape)
users.head(5)
# Out:
# Shape:  (12407, 19)
#           username          displayname               userId  \
# 0  ArjunSinghPanam    Arjun Singh Panam             45091142
# 1       PrdeepNain         Pradeep Nain  1355092620662329349
# 2    anmoldhaliwal                Anmol            137908912
# 5   ShariaActivist  Sharia Ali Siddique  1362487487747121152
# 6  KaurDosanjh1979                Red 💚            538638801
#
#                                       rawDescription descriptionUrls  \
# 0  Global Citizen, Actor, Director: Sky is the ro...              []
# 1              Live in the sunshine where you belong              []
# 2                                        coming soon              []
# 5  Little Climate & Environmental Activist | Foun...              []
# 6                                                                 []
#
#    verified                    created  followersCount  friendsCount  \
# 0     False  2009-06-06T07:50:57+00:00             603           311
# 1     False  2021-01-29T09:58:06+00:00              14           134
# 2     False  2010-04-28T03:12:18+00:00              51            27
# 5     False  2021-02-18T19:41:57+00:00              46           106
# 6     False  2012-03-27T23:14:32+00:00             427          1005
#
#    statusesCount  favouritesCount  listedCount  mediaCount      location  \
# 0          17534             4269           23        1211
# 1            160              240            0         102
# 2            228               77            0          12  Brampton, On
# 5            112               60            0          53      she/they
# 6          29803            18962            0          30
#
#    protected                              linkUrl  \
# 0      False  https://www.cosmosmovieofficial.com
# 1      False                                 None
# 2      False                                 None
# 5      False                                 None
# 6      False                                 None
#
#                                      profileImageUrl  \
# 0  https://pbs.twimg.com/profile_images/121554174...
# 1  https://pbs.twimg.com/profile_images/136417063...
# 2  https://pbs.twimg.com/profile_images/156497514...
# 5  https://pbs.twimg.com/profile_images/136428288...
# 6  https://pbs.twimg.com/profile_images/135582023...
#
#                                     profileBannerUrl  \
# 0  https://pbs.twimg.com/profile_banners/45091142...
# 1  https://pbs.twimg.com/profile_banners/13550926...
# 2                                               None
# 5  https://pbs.twimg.com/profile_banners/13624874...
# 6  https://pbs.twimg.com/profile_banners/53863880...
#
#                             profileUrl
# 0  https://twitter.com/ArjunSinghPanam
# 1       https://twitter.com/PrdeepNain
# 2    https://twitter.com/anmoldhaliwal
# 5   https://twitter.com/ShariaActivist
# 6  https://twitter.com/KaurDosanjh1979

# %%
user_id = []
for user in raw_tweets['user']:
    uid = user['id']
    user_id.append(uid)
raw_tweets['userId'] = user_id

# Remove less important columns
cols = ['url', 'date', 'renderedContent', 'id', 'userId', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount', 'source', 'media', 'retweetedTweet', 'quotedTweet', 'mentionedUsers']
tweets = raw_tweets[cols]
tweets.rename(columns={'id':'tweetId', 'url':'tweetUrl'}, inplace=True)
tweets.head(5)
# Out:
#                                              tweetUrl  \
# 0   https://twitter.com/ArjunSinghPanam/status/136...
# 1   https://twitter.com/PrdeepNain/status/13645062...
# 3   https://twitter.com/anmoldhaliwal/status/13645...
# 8   https://twitter.com/anmoldhaliwal/status/13645...
# 11  https://twitter.com/anmoldhaliwal/status/13645...
#
#                         date  \
# 0  2021-02-24 09:23:35+00:00
# 1  2021-02-24 09:23:32+00:00
# 3  2021-02-24 09:23:16+00:00
# 8  2021-02-24 09:22:34+00:00
# 11 2021-02-24 09:21:51+00:00
#
#                                       renderedContent              tweetId  \
# 0   The world progresses while the Indian police a...  1364506249291784198
# 1   #FarmersProtest \n#ModiIgnoringFarmersDeaths \...  1364506237451313155
# 3   @ReallySwara @rohini_sgh watch full video here...  1364506167226032128
# 8   @mandeeppunia1 watch full video here youtu.be/...  1364505991887347714
# 11  @mandeeppunia1 watch full video here youtu.be/...  1364505813834989568
#
#                  userId  replyCount  retweetCount  likeCount  quoteCount  \
# 0              45091142           0             0          0           0
# 1   1355092620662329349           0             0          0           0
# 3             137908912           0             0          0           0
# 8             137908912           0             0          0           0
# 11            137908912           0             0          0           0
#
#                                                source  \
# 0   <a href="http://twitter.com/download/iphone" r...
# 1   <a href="http://twitter.com/download/android" ...
# 3   <a href="https://mobile.twitter.com" rel="nofo...
# 8   <a href="https://mobile.twitter.com" rel="nofo...
# 11  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                                 media  retweetedTweet  \
# 0                                                None             NaN
# 1   [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...             NaN
# 3   [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...             NaN
# 8   [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...             NaN
# 11  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...             NaN
#
#                                           quotedTweet  \
# 0   {'url': 'https://twitter.com/RaviSinghKA/statu...
# 1                                                None
# 3                                                None
# 8                                                None
# 11                                               None
#
#                                        mentionedUsers
# 0   [{'username': 'narendramodi', 'displayname': '...
# 1   [{'username': 'Kisanektamorcha', 'displayname'...
# 3   [{'username': 'ReallySwara', 'displayname': 'S...
# 8   [{'username': 'mandeeppunia1', 'displayname': ...
# 11  [{'username': 'mandeeppunia1', 'displayname': ...

# %%
tweets = pd.DataFrame(tweets)
tweets.drop_duplicates(subset=['tweetId'], inplace=True)
print("Shape: ", tweets.shape)
tweets.head(5)
# Out:
# Shape:  (48429, 14)
#                                              tweetUrl  \
# 0   https://twitter.com/ArjunSinghPanam/status/136...
# 1   https://twitter.com/PrdeepNain/status/13645062...
# 3   https://twitter.com/anmoldhaliwal/status/13645...
# 8   https://twitter.com/anmoldhaliwal/status/13645...
# 11  https://twitter.com/anmoldhaliwal/status/13645...
#
#                         date  \
# 0  2021-02-24 09:23:35+00:00
# 1  2021-02-24 09:23:32+00:00
# 3  2021-02-24 09:23:16+00:00
# 8  2021-02-24 09:22:34+00:00
# 11 2021-02-24 09:21:51+00:00
#
#                                       renderedContent              tweetId  \
# 0   The world progresses while the Indian police a...  1364506249291784198
# 1   #FarmersProtest \n#ModiIgnoringFarmersDeaths \...  1364506237451313155
# 3   @ReallySwara @rohini_sgh watch full video here...  1364506167226032128
# 8   @mandeeppunia1 watch full video here youtu.be/...  1364505991887347714
# 11  @mandeeppunia1 watch full video here youtu.be/...  1364505813834989568
#
#                  userId  replyCount  retweetCount  likeCount  quoteCount  \
# 0              45091142           0             0          0           0
# 1   1355092620662329349           0             0          0           0
# 3             137908912           0             0          0           0
# 8             137908912           0             0          0           0
# 11            137908912           0             0          0           0
#
#                                                source  \
# 0   <a href="http://twitter.com/download/iphone" r...
# 1   <a href="http://twitter.com/download/android" ...
# 3   <a href="https://mobile.twitter.com" rel="nofo...
# 8   <a href="https://mobile.twitter.com" rel="nofo...
# 11  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                                 media  retweetedTweet  \
# 0                                                None             NaN
# 1   [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...             NaN
# 3   [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...             NaN
# 8   [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...             NaN
# 11  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...             NaN
#
#                                           quotedTweet  \
# 0   {'url': 'https://twitter.com/RaviSinghKA/statu...
# 1                                                None
# 3                                                None
# 8                                                None
# 11                                               None
#
#                                        mentionedUsers
# 0   [{'username': 'narendramodi', 'displayname': '...
# 1   [{'username': 'Kisanektamorcha', 'displayname'...
# 3   [{'username': 'ReallySwara', 'displayname': 'S...
# 8   [{'username': 'mandeeppunia1', 'displayname': ...
# 11  [{'username': 'mandeeppunia1', 'displayname': ...

# %% [markdown]
# ## Escribo en ingles los enunciados siguientes por un tema de notación de código y no perder la consistencia

# %% [markdown]
# ### top 10 most retweeted tweets

# %%
tweets.nlargest(n=10, columns=['retweetCount'])
# Out:
#                                                  tweetUrl  \
# 7645    https://twitter.com/dhruv_rathee/status/136414...
# 89780   https://twitter.com/rupikaur_/status/136088206...
# 88911   https://twitter.com/amaanbali/status/136090860...
# 111556  https://twitter.com/jedijasmin_/status/1360162...
# 64492   https://twitter.com/rupikaur_/status/136179092...
# 108072  https://twitter.com/RaviSinghKA/status/1360260...
# 84368   https://twitter.com/sushant_says/status/136103...
# 23348   https://twitter.com/amaanbali/status/136342152...
# 89423   https://twitter.com/avinashkalla/status/136089...
# 97348   https://twitter.com/Monica_Gill1/status/136062...
#
#                             date  \
# 7645   2021-02-23 09:40:21+00:00
# 89780  2021-02-14 09:22:23+00:00
# 88911  2021-02-14 11:07:50+00:00
# 111556 2021-02-12 09:44:31+00:00
# 64492  2021-02-16 21:33:51+00:00
# 108072 2021-02-12 16:11:35+00:00
# 84368  2021-02-14 19:38:29+00:00
# 23348  2021-02-21 09:33:17+00:00
# 89423  2021-02-14 10:08:51+00:00
# 97348  2021-02-13 16:08:24+00:00
#
#                                           renderedContent  \
# 7645    There's a #FarmersProtest happening in Germany...
# 89780   disha ravi, a 21-year-old climate activist, ha...
# 88911   Disha Ravi broke down in court room and told j...
# 111556  Farmers are so sweet. Y’all have to see this @...
# 64492   india is targeting young women to silence diss...
# 108072  Bollywood has betrayed Panjab &amp; the farmer...
# 84368   Please, where did you get your PhD from? Anti-...
# 23348   This is Revolution. More than 2.25lac people a...
# 89423   Wish you fly over the Delhi border and look at...
# 97348   They went after our grandparents.\n#GurmukhSin...
#
#                     tweetId              userId  replyCount  retweetCount  \
# 7645    1364148079117615105  730520573701443584         666          6164
# 89780   1360882069161803779           462119058         655          4673
# 88911   1360908603155050498            70364936         282          3742
# 111556  1360162861419425795          3283097888         170          3332
# 64492   1361790921902338048           462119058         278          3230
# 108072  1360260269646237699          2347762888         294          3182
# 84368   1361037112783499264           185609127         425          2495
# 23348   1363421524879843336            70364936         112          2258
# 89423   1360893759173500930            74947226         122          2208
# 97348   1360621855749644289            71129057         133          1933
#
#         likeCount  quoteCount  \
# 7645        27888         221
# 89780        8974         388
# 88911       10403         239
# 111556      17325         175
# 64492        7244         230
# 108072      12949         205
# 84368        9780          98
# 23348        7574         171
# 89423       12273          53
# 97348        6478         148
#
#                                                    source  \
# 7645    <a href="http://twitter.com/download/iphone" r...
# 89780   <a href="https://mobile.twitter.com" rel="nofo...
# 88911   <a href="http://twitter.com/download/iphone" r...
# 111556  <a href="http://twitter.com/download/iphone" r...
# 64492   <a href="https://mobile.twitter.com" rel="nofo...
# 108072  <a href="http://twitter.com/download/iphone" r...
# 84368   <a href="http://twitter.com/download/iphone" r...
# 23348   <a href="http://twitter.com/download/iphone" r...
# 89423   <a href="http://twitter.com/download/iphone" r...
# 97348   <a href="http://twitter.com/download/iphone" r...
#
#                                                     media  retweetedTweet  \
# 7645    [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
# 89780                                                None             NaN
# 88911                                                None             NaN
# 111556  [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
# 64492                                                None             NaN
# 108072                                               None             NaN
# 84368                                                None             NaN
# 23348   [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
# 89423                                                None             NaN
# 97348   [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
#
#                                               quotedTweet  \
# 7645                                                 None
# 89780                                                None
# 88911                                                None
# 111556                                               None
# 64492                                                None
# 108072                                               None
# 84368   {'url': 'https://twitter.com/TrulyMonica/statu...
# 23348                                                None
# 89423   {'url': 'https://twitter.com/narendramodi/stat...
# 97348                                                None
#
#                                            mentionedUsers
# 7645                                                 None
# 89780   [{'username': 'GretaThunberg', 'displayname': ...
# 88911                                                None
# 111556  [{'username': 'AmandaCerny', 'displayname': 'A...
# 64492                                                None
# 108072                                               None
# 84368                                                None
# 23348                                                None
# 89423                                                None
# 97348                                                None

# %% [markdown]
# ### top 10 users with most tweets

# %%
most_tweets = tweets["userId"].value_counts().reset_index()
most_tweets.columns = ["userId", "count"]

# %%
most_tweets.head(10)
# Out:
#                 userId  count
# 0            452391771    679
# 1           2930682630    489
# 2            538638801    423
# 3  1309302936317636608    368
# 4            622149895    366
# 5  1337221335282434049    362
# 6  1354532795847073796    339
# 7  1334770554247602178    334
# 8           2350985978    317
# 9            217105273    298

# %%
top_users = most_tweets.head(10)
list_top_users = top_users["userId"].values.tolist()

# %%
list_top_users
# Out:
# [452391771,
#  2930682630,
#  538638801,
#  1309302936317636608,
#  622149895,
#  1337221335282434049,
#  1354532795847073796,
#  1334770554247602178,
#  2350985978,
#  217105273]

# %%
users[users['userId'].isin(list_top_users)]
# Out:
#              username                                        displayname  \
# 6     KaurDosanjh1979                                              Red 💚
# 86    DigitalKisanBot                                        Kisan Bot🚜🌾
# 183   shells_n_petals  Jaspal Kaur Bains.For love of Punjab,Sikhi & I...
# 314       AhluwaliaA2                                         AhluwaliaA
# 600            jot__b                                                Jot
# 1066    loyal90901246                                              loyal
# 1220         ish_kayy                                               ishy
# 1515    rebelpacifist                                Theinactiveactivist
# 1636       mani262002                              Jai Jawan Jai Kisan 🙏
# 4270       Surrypuria                                           Surrypur
#
#                    userId                                     rawDescription  \
# 6               538638801
# 86    1309302936317636608  ਕਿਸਾਨਾਂ ਦੇ ਸਮਰਥਨ ਵਿੱਚ ਪਹਿਲਾ ਟਵਿੱਟਰ ਬੌਟ\nਇਹ Bot...
# 183            2930682630  Speak up and  stand with the Farmers and fello...
# 314   1337221335282434049                               #IStandWithFarmers🚜🌽
# 600             452391771
# 1066  1334770554247602178
# 1220            622149895                              Authenticity is key🗝️
# 1515  1354532795847073796  Believe in Human Rights Civil Rights Love for ...
# 1636           2350985978                                     SupportFarmers
# 4270            217105273           Farmers lives matter, no farmers no food
#
#      descriptionUrls  verified                    created  followersCount  \
# 6                 []     False  2012-03-27T23:14:32+00:00             427
# 86                []     False  2020-09-25T01:25:36+00:00            2331
# 183               []     False  2014-12-15T07:59:03+00:00             378
# 314               []     False  2020-12-11T02:23:21+00:00             139
# 600               []     False  2012-01-01T19:55:54+00:00              58
# 1066              []     False  2020-12-04T08:05:15+00:00              70
# 1220              []     False  2012-06-29T18:51:56+00:00             137
# 1515              []     False  2021-01-27T20:52:52+00:00             112
# 1636              []     False  2014-02-19T02:23:01+00:00              59
# 4270              []     False  2010-11-18T16:06:24+00:00             156
#
#       friendsCount  statusesCount  favouritesCount  listedCount  mediaCount  \
# 6             1005          29803            18962            0          30
# 86              65          19022             2544            3         153
# 183            787           8405             8721            0         105
# 314            147           9412                0            0         166
# 600            279           2579             2530            0          40
# 1066           377           4382            16265            0         141
# 1220           524           2116             4477            1          52
# 1515           230           5369             3886            0          31
# 1636           116           7163             4316            0         807
# 4270           243           4318             4347            0          86
#
#                       location  protected linkUrl  \
# 6                                   False    None
# 86                 Atlanta, GA      False    None
# 183                                 False    None
# 314                                 False    None
# 600           Toronto, Ontario      False    None
# 1066                                False    None
# 1220               Ontario, CA      False    None
# 1515                                False    None
# 1636                                False    None
# 4270  British Columbia, Canada      False    None
#
#                                         profileImageUrl  \
# 6     https://pbs.twimg.com/profile_images/135582023...
# 86    https://pbs.twimg.com/profile_images/135422427...
# 183   https://pbs.twimg.com/profile_images/134037097...
# 314   https://pbs.twimg.com/profile_images/135415348...
# 600   https://pbs.twimg.com/profile_images/135827486...
# 1066  https://pbs.twimg.com/profile_images/135405835...
# 1220  https://pbs.twimg.com/profile_images/135826466...
# 1515  https://pbs.twimg.com/profile_images/135662571...
# 1636  https://pbs.twimg.com/profile_images/135575567...
# 4270  https://pbs.twimg.com/profile_images/136041912...
#
#                                        profileBannerUrl  \
# 6     https://pbs.twimg.com/profile_banners/53863880...
# 86    https://pbs.twimg.com/profile_banners/13093029...
# 183   https://pbs.twimg.com/profile_banners/29306826...
# 314                                                None
# 600                                                None
# 1066  https://pbs.twimg.com/profile_banners/13347705...
# 1220  https://pbs.twimg.com/profile_banners/62214989...
# 1515  https://pbs.twimg.com/profile_banners/13545327...
# 1636  https://pbs.twimg.com/profile_banners/23509859...
# 4270  https://pbs.twimg.com/profile_banners/21710527...
#
#                                profileUrl
# 6     https://twitter.com/KaurDosanjh1979
# 86    https://twitter.com/DigitalKisanBot
# 183   https://twitter.com/shells_n_petals
# 314       https://twitter.com/AhluwaliaA2
# 600            https://twitter.com/jot__b
# 1066    https://twitter.com/loyal90901246
# 1220         https://twitter.com/ish_kayy
# 1515    https://twitter.com/rebelpacifist
# 1636       https://twitter.com/mani262002
# 4270       https://twitter.com/Surrypuria

# %% [markdown]
# ### Top 10 days with most tweets

# %% [markdown]
# #### First remove the time in the timestamp column by transforming it to only time type

# %%
tweets['dateNots'] = pd.to_datetime(tweets['date'])
tweets['daydate'] = tweets['dateNots'].dt.date

# %% [markdown]
# #### Now lets groupby and count like we did in the previous example

# %%
best_day = tweets["daydate"].value_counts().reset_index()
best_day.columns = ["date", "tweet count"]

# %%
top_days = best_day.head(10)
list_top_days = top_days["date"].values.tolist()

# %%
top_days
# Out:
#          date  tweet count
# 0  2021-02-17         4516
# 1  2021-02-12         4423
# 2  2021-02-15         4407
# 3  2021-02-14         4350
# 4  2021-02-16         4343
# 5  2021-02-13         4124
# 6  2021-02-20         3730
# 7  2021-02-18         3701
# 8  2021-02-23         3566
# 9  2021-02-19         3540

# %% [markdown]
# ### get the top 10 most used hashtags
